# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904897-hash/cau_lenh/blob/main/for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("nhập số nguyên dương:"))
s = 0
for i in range(0, n + 1):
  s += i
print(f"Tổng các số nguyên dương cộng dồn {i} là: {s}")
# Out:
# nhập số nguyên dương:3
# Tổng các số nguyên dương cộng dồn 3 là: 6
