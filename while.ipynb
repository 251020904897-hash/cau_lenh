# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904897-hash/cau_lenh/blob/main/while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("nhập số nguyên dương:"))
s = 0
i = 0
while i < n:
  s += i
  i += 2
print(f"Tổng các số nguyên dương nhỏ hơn {n} là: {s}")
# Out:
# nhập số nguyên dương:10
# Tổng các số nguyên dương nhỏ hơn 10 là: 20
